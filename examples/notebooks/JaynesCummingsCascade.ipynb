# %% [markdown]
# # A cascade of two open Jaynes-Cummings CQED Cavity models

# %%
from qnet.algebra.circuit_algebra import *
from qnet.circuit_components.displace_cc import Displace as Displace_cc

def SLH_JaynesCummings(Delta, Theta, g, kappa, gamma, namespace = ''):
    
    # create Fock- and Atom local spaces 
    fock = local_space('fock', namespace = namespace)
    tls = local_space('tls', namespace = namespace, basis = ('e', 'g'))
    
    # create representations of a and sigma
    a = Destroy(fock)
    sigma = LocalSigma(tls, 'g', 'e')
    
    # Trivial scattering matrix
    S = identity_matrix(2)
    
    # Collapse/Jump operators
    L1 = sqrt(kappa) * a                                    # Decay of cavity mode through mirror
    L2 = sqrt(gamma) * sigma                                # Atomic decay due to spontaneous emission into outside modes.
    L = Matrix([[L1], 
                [L2]])
    
    # Hamilton operator
    H = (Delta * sigma.dag() * sigma                        # detuning from atomic resonance
        + Theta * a.dag() * a                               # detuning from cavity resonance
        + I * g * (sigma * a.dag() - sigma.dag() * a))      # atom-mode coupling, I = sqrt(-1)
    
    return SLH(S, L, H)

# symbolic parameters
Delta, Theta, g = symbols('Delta, Theta,  g', real = True)  # Hamiltonian parameters
kappa, gamma = symbols('kappa, gamma', positive = True)     # Decay rates
alpha = symbols('alpha')                                    # External driving amplitude

# circuit component models
JC1 = SLH_JaynesCummings(Delta, Theta, g, kappa, gamma, namespace = 'jc1')  # first model
JC2 = SLH_JaynesCummings(Delta, Theta, g, kappa, gamma, namespace = 'jc2')  # second model
W_alpha = Displace_cc('W_alpha', alpha = alpha)                             # coherent displacement

# circuit expression
SYS = (JC2 + cid(1)) << P_sigma(0, 2, 1) << (JC1 + cid(1)) << (W_alpha + cid(2))

# %%
SYS.show()

# %%
SYSSLH = SYS.toSLH().expand()
SYSSLH
# Out:
# SLH(Matrix([[1, 0, 0], [0, 0, 1], [0, 1, 0]]), Matrix([[OperatorPlus(ScalarTimesOperator(alpha, IdentityOperator), ScalarTimesOperator(kappa**(1/2), Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(kappa**(1/2), Destroy(LocalSpace('fock', 'jc2'))))], [ScalarTimesOperator(gamma**(1/2), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e'))], [ScalarTimesOperator(gamma**(1/2), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e'))]]), OperatorPlus(ScalarTimesOperator(-I*alpha*kappa**(1/2)/2, Create(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(-I*alpha*kappa**(1/2)/2, Create(LocalSpace('fock', 'jc2'))), ScalarTimesOperator(I*kappa**(1/2)*conjugate(alpha)/2, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(I*kappa**(1/2)*conjugate(alpha)/2, Destroy(LocalSpace('fock', 'jc2'))), ScalarTimesOperator(Delta, LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'e')), ScalarTimesOperator(Delta, LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'e')), ScalarTimesOperator(Theta, OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc1')))), ScalarTimesOperator(I*kappa/2, OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc2')))), ScalarTimesOperator(I*g, OperatorTimes(Create(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e'))), ScalarTimesOperator(Theta, OperatorTimes(Create(LocalSpace('fock', 'jc2')), Destroy(LocalSpace('fock', 'jc2')))), ScalarTimesOperator(I*g, OperatorTimes(Create(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e'))), ScalarTimesOperator(-I*kappa/2, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), Create(LocalSpace('fock', 'jc2')))), ScalarTimesOperator(-I*g, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g'))), ScalarTimesOperator(-I*g, OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g')))))

# %%
SYS.space
# Out:
# ProductSpace(LocalSpace('fock', 'jc1'), LocalSpace('fock', 'jc2'), LocalSpace('tls', 'jc1'), LocalSpace('tls', 'jc2'))

# %%
fjc1, fjc2, ajc1, ajc2 = SYS.space.operands
a1 = Destroy(fjc1)
a2 = Destroy(fjc2)
s1 = LocalSigma(ajc1, 'g', 'e')
s2 = LocalSigma(ajc2, 'g', 'e')
Z1 = LocalProjector(ajc1, 'e') - LocalProjector(ajc1, 'g')
Z2 = LocalProjector(ajc2, 'e') - LocalProjector(ajc2, 'g')

# %% [markdown]
# ## Compute the Heisenberg Equations of Motion for $a_1, a_2, \sigma^{(1)}, \sigma^{(2)}, Z^{(1)}, Z^{(2)}$

# %%
SYSSLH.symbolic_heisenberg_eom(a1).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-alpha*kappa**(1/2), IdentityOperator), ScalarTimesOperator(-I*Theta - kappa/2, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(g, LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')))

# %%
SYSSLH.symbolic_heisenberg_eom(a2).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-alpha*kappa**(1/2), IdentityOperator), ScalarTimesOperator(-kappa, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(-I*Theta - kappa/2, Destroy(LocalSpace('fock', 'jc2'))), ScalarTimesOperator(g, LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')))

# %%
SYSSLH.symbolic_heisenberg_eom(s1).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-I*Delta - gamma/2, LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')), ScalarTimesOperator(g, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'e'))), ScalarTimesOperator(-g, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'g'))))

# %%
SYSSLH.symbolic_heisenberg_eom(s2).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-I*Delta - gamma/2, LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')), ScalarTimesOperator(g, OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'e'))), ScalarTimesOperator(-g, OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'g'))))

# %%
SYSSLH.symbolic_heisenberg_eom(Z1).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-2*gamma, LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'e')), ScalarTimesOperator(-2*g, OperatorTimes(Create(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e'))), ScalarTimesOperator(-2*g, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g'))))

# %%
SYSSLH.symbolic_heisenberg_eom(Z2).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-2*gamma, LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'e')), ScalarTimesOperator(-2*g, OperatorTimes(Create(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e'))), ScalarTimesOperator(-2*g, OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g'))))

# %% [markdown]
# ## Compute the symbolic Liouville super operator $\mathcal{L}$

# %%
LL = SYSSLH.symbolic_liouvillian().expand()
LL
# Out:
# SuperOperatorPlus(ScalarTimesSuperOperator(alpha*kappa**(1/2), SPost(Create(LocalSpace('fock', 'jc1')))), ScalarTimesSuperOperator(alpha*kappa**(1/2), SPost(Create(LocalSpace('fock', 'jc2')))), ScalarTimesSuperOperator(-kappa**(1/2)*conjugate(alpha), SPost(Destroy(LocalSpace('fock', 'jc1')))), ScalarTimesSuperOperator(-kappa**(1/2)*conjugate(alpha), SPost(Destroy(LocalSpace('fock', 'jc2')))), ScalarTimesSuperOperator(I*Delta - gamma/2, SPost(LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'e'))), ScalarTimesSuperOperator(I*Delta - gamma/2, SPost(LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'e'))), ScalarTimesSuperOperator(I*Theta - kappa/2, SPost(OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc1'))))), ScalarTimesSuperOperator(-kappa, SPost(OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(-g, SPost(OperatorTimes(Create(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')))), ScalarTimesSuperOperator(I*Theta - kappa/2, SPost(OperatorTimes(Create(LocalSpace('fock', 'jc2')), Destroy(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(-g, SPost(OperatorTimes(Create(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')))), ScalarTimesSuperOperator(g, SPost(OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g')))), ScalarTimesSuperOperator(g, SPost(OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g')))), ScalarTimesSuperOperator(-alpha*kappa**(1/2), SPre(Create(LocalSpace('fock', 'jc1')))), ScalarTimesSuperOperator(-alpha*kappa**(1/2), SPre(Create(LocalSpace('fock', 'jc2')))), ScalarTimesSuperOperator(kappa**(1/2)*conjugate(alpha), SPre(Destroy(LocalSpace('fock', 'jc1')))), ScalarTimesSuperOperator(kappa**(1/2)*conjugate(alpha), SPre(Destroy(LocalSpace('fock', 'jc2')))), ScalarTimesSuperOperator(-I*Delta - gamma/2, SPre(LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'e'))), ScalarTimesSuperOperator(-I*Delta - gamma/2, SPre(LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'e'))), ScalarTimesSuperOperator(-I*Theta - kappa/2, SPre(OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc1'))))), ScalarTimesSuperOperator(g, SPre(OperatorTimes(Create(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')))), ScalarTimesSuperOperator(-I*Theta - kappa/2, SPre(OperatorTimes(Create(LocalSpace('fock', 'jc2')), Destroy(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(g, SPre(OperatorTimes(Create(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')))), ScalarTimesSuperOperator(-kappa, SPre(OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), Create(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(-g, SPre(OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g')))), ScalarTimesSuperOperator(-g, SPre(OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g')))), ScalarTimesSuperOperator(kappa, SuperOperatorTimes(SPre(Destroy(LocalSpace('fock', 'jc1'))), SPost(Create(LocalSpace('fock', 'jc1'))))), ScalarTimesSuperOperator(kappa, SuperOperatorTimes(SPre(Destroy(LocalSpace('fock', 'jc1'))), SPost(Create(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(kappa, SuperOperatorTimes(SPre(Destroy(LocalSpace('fock', 'jc2'))), SPost(Create(LocalSpace('fock', 'jc1'))))), ScalarTimesSuperOperator(kappa, SuperOperatorTimes(SPre(Destroy(LocalSpace('fock', 'jc2'))), SPost(Create(LocalSpace('fock', 'jc2'))))), ScalarTimesSuperOperator(gamma, SuperOperatorTimes(SPre(LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')), SPost(LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g')))), ScalarTimesSuperOperator(gamma, SuperOperatorTimes(SPre(LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')), SPost(LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g')))))

# %% [markdown]
# ### Compute the super-adjoint $\mathcal{L}^*$ of the Liouvillian and apply it to $a_1$

# %%
(LL.superadjoint() * a1).expand()
# Out:
# OperatorPlus(ScalarTimesOperator(-alpha*kappa**(1/2), IdentityOperator), ScalarTimesOperator(-I*Theta - kappa/2, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(g, LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')))

# %% [markdown]
# ## Numerical Analysis with QuTiP

# %% [markdown]
# We need to specify the dimensions of the local fock space degrees of freedom!

# %%
NFock = 20
fjc1.dimension = NFock
fjc2.dimension = NFock

# %%
a1.space.dimension
# Out:
# 20

# %%
SYS.space.dimension
# Out:
# 1600

# %%
numerical_params = {
                    alpha: 5.,
                    g: 20.,
                    kappa: 9.,
                    gamma: 1.,
                    Delta: 0.,
                    Theta: 0.,
                   }
SYSSLHN = SYSSLH.substitute(numerical_params)
SYSSLHN
# Out:
# SLH(Matrix([[1, 0, 0], [0, 0, 1], [0, 1, 0]]), Matrix([[OperatorPlus(ScalarTimesOperator(5.00000000000000, IdentityOperator), ScalarTimesOperator(3.00000000000000, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(3.00000000000000, Destroy(LocalSpace('fock', 'jc2'))))], [LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e')], [LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e')]]), OperatorPlus(ScalarTimesOperator(-7.5*I, Create(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(-7.5*I, Create(LocalSpace('fock', 'jc2'))), ScalarTimesOperator(7.5*I, Destroy(LocalSpace('fock', 'jc1'))), ScalarTimesOperator(7.5*I, Destroy(LocalSpace('fock', 'jc2'))), ScalarTimesOperator(4.5*I, OperatorTimes(Create(LocalSpace('fock', 'jc1')), Destroy(LocalSpace('fock', 'jc2')))), ScalarTimesOperator(20.0*I, OperatorTimes(Create(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'g', 'e'))), ScalarTimesOperator(20.0*I, OperatorTimes(Create(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'g', 'e'))), ScalarTimesOperator(-4.5*I, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), Create(LocalSpace('fock', 'jc2')))), ScalarTimesOperator(-20.0*I, OperatorTimes(Destroy(LocalSpace('fock', 'jc1')), LocalSigma(LocalSpace('tls', 'jc1'), 'e', 'g'))), ScalarTimesOperator(-20.0*I, OperatorTimes(Destroy(LocalSpace('fock', 'jc2')), LocalSigma(LocalSpace('tls', 'jc2'), 'e', 'g')))))

# %%
H, Ls = SYSSLHN.HL_to_qutip()

# %%
obs = [a1.dag() + a1, a2.dag() + a2, Z1, Z2]
obsqt = [o.to_qutip(SYS.space) for o in obs]

# %%
SYS.space
# Out:
# ProductSpace(LocalSpace('fock', 'jc1'), LocalSpace('fock', 'jc2'), LocalSpace('tls', 'jc1'), LocalSpace('tls', 'jc2'))

# %%
fvac = qutip.basis(NFock, 0)
ag = qutip.basis(2, 1)

# need to reproduce correct ordering of local spaces in tensor product
psi0 = qutip.tensor(fvac, fvac, ag, ag)

# %%
times = arange(0, 100., .1)
data = qutip.mcsolve(H, psi0, times, Ls, obsqt, ntraj = 1)
# Out:
# 100.0%  (1/1)  Est. time remaining: 00:00:00:00

# %%
figure(figsize = (10, 8))
plot(times, data.expect.T)
legend([r"$\left\langle {} \right\rangle$".format(o.tex()) for o in obs])
xlabel('time $t$')
